# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from sklearn.linear_model import Ridge, Lasso
from sklearn.svm import SVR
import lightgbm as lgb

from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.neural_network import MLPRegressor
import re 
import scipy
from scipy import sparse
import gc 

from IPython.display import display
from pprint import pprint
from matplotlib import pyplot as plt 
import pickle


import time
import scipy.optimize as optimize
import warnings


from datetime import datetime 
import psutil

warnings.filterwarnings("ignore")
pd.options.display.max_colwidth=300
pd.options.display.max_columns = 100

# %%
def timer(func):
    def wrapper(*args, **kws):
        st = time.time()
        res = func(*args, **kws)
        et = time.time()
        tt = (et-st)/60
        print(f'Time taken is {tt:.2f} mins')
        return res
    return wrapper

# %%
# first competition dataset

df_class_train = pd.read_csv("../input/jigsaw-toxic-comment-classification-challenge/train.csv")
# df_class_test = pd.read_csv("../input/jigsaw-toxic-comment-classification-challenge/test.csv")
# df_class_test_label=pd.read_csv("../input/jigsaw-toxic-comment-classification-challenge/test_labels.csv").replace(-1,0)
# df_class_test = pd.merge(df_class_test, df_class_test_label, how="left", on = "id")
df_class_train['severe_toxic'] = df_class_train.severe_toxic * 2
df_class_train['y'] = (df_class_train[['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']].sum(axis=1) ).astype(int) 
df_class_train['y'] = df_class_train['y']/df_class_train['y'].max()
df_class_train = df_class_train[['comment_text', 'y']].rename(columns={'comment_text': 'text'})

# df_class_train[df_class_train.y>0].sort_values(by=['y'],ascending=False)

# %%
# large_train is add the worker infomation
# df_bias_large_train=pd.read_csv(('../input/jigsaw-unintended-bias-in-toxicity-classification/toxicity_individual_annotations.csv'))

df_bias_train=pd.read_csv(('../input/jigsaw-unintended-bias-in-toxicity-classification/train.csv'))

toxic_relevance=['severe_toxicity', 'obscene','identity_attack', 'insult', 'threat']
# df_bias_train=df_bias_train[toxic_relevance]
df_bias_train['severe_toxicity'] = df_bias_train.severe_toxicity * 2
df_bias_train['y'] = (df_bias_train[toxic_relevance].sum(axis=1) ).astype(int) 
df_bias_train['y'] = df_bias_train['y']/df_bias_train['y'].max()
df_bias_train = df_bias_train[['comment_text', 'y']].rename(columns={'comment_text': 'text'})


toxic_count=df_bias_train[df_bias_train.y>0].shape[0]
sample_number=int(2e5)
df_bias_train=df_bias_train.sample(n=sample_number,random_state=1, axis=0).append(df_bias_train[df_bias_train.y>0])

# df_bias_train

# %%
# third competition dataset
df_multi_train = pd.read_csv("../input/jigsaw-multilingual-toxic-comment-classification/jigsaw-toxic-comment-train.csv")
df_multi_train['severe_toxic'] = df_multi_train.severe_toxic * 2
df_multi_train['y'] = (df_multi_train[['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']].sum(axis=1) ).astype(int)
df_multi_train['y'] = df_multi_train['y']/df_multi_train['y'].max()
df_multi_train = df_multi_train[['comment_text', 'y']].rename(columns={'comment_text': 'text'})
# df_multi_train

# %%
# print(len(set(df_class_train.text.unique()) & set(df_multi_train.text.unique())))
# print(len(set(df_class_train.text.unique())))
# print(len(set(df_multi_train.text.unique())))
# print(len(set(df_bias_train.text.unique()) & set(df_multi_train.text.unique())))

# %%
# ruddit dataset 
df_ruddit_train=pd.read_csv("../input/ruddit-jigsaw-dataset/Dataset/ruddit_with_text.csv")
df_ruddit_train = df_ruddit_train[['txt', 'offensiveness_score']].rename(columns={'txt': 'text',
                                                                'offensiveness_score':'y'})
df_ruddit_train['y'] = (df_ruddit_train['y'] - df_ruddit_train.y.min()) / (df_ruddit_train.y.max() - df_ruddit_train.y.min()) 
# df_ruddit_train.shape

# %%
df_rate_score=pd.read_csv("../input/jigsaw-toxic-severity-rating/comments_to_score.csv")
df_rate_sub=pd.read_csv("../input/jigsaw-toxic-severity-rating/sample_submission.csv")
df_rate_val=pd.read_csv("../input/jigsaw-toxic-severity-rating/validation_data.csv")

# %%
class DataCleaner_v0(BaseEstimator, TransformerMixin):
    def __init__(self): # no *args and **kwargs
        super().__init__()
    
    def fit(self, X, y=None):
        return self  # nothing else to do
    
    def transform(self, X, y=None):   

        # Clean some punctutations
        data_temp=X.copy()
        data_temp = data_temp.str.replace('\n', ' \n ')
        # Remove ip address
        data_temp =    data_temp.str.replace(r'(([0-9]+\.){2,}[0-9]+)',' ')
        data_temp = data_temp.str.replace(r'([a-zA-Z]+)([/!?.])([a-zA-Z]+)',r'\1 \2 \3')
        # Replace repeating characters more than 3 times to length of 3
        data_temp= data_temp.str.replace(r'([*!?\'])\1\1{2,}',r'\1\1\1')
        # patterns with repeating characters 
        data_temp = data_temp.str.replace(r'([a-zA-Z])\1{2,}\b',r'\1\1')
        data_temp =data_temp.str.replace(r'([a-zA-Z])\1\1{2,}\B',r'\1\1\1')
        data_temp = data_temp.str.replace(r'[ ]{2,}',' ').str.strip()   
        # Add space around repeating characters
        data_temp =data_temp.str.replace(r'([*!?\']+)',r' \1 ')     
        return data_temp


class DataCleaner_v1(BaseEstimator, TransformerMixin):
    def __init__(self): # no *args and **kwargs
        super().__init__()
    
    def fit(self, X, y=None):
        return self  # nothing else to do
    
    def transform(self, X, y=None):   
        '''
                Cleans text into a basic form for NLP. Operations include the following:-
                1. Remove special charecters like &, #, etc
                2. Removes extra spaces
                3. Removes embedded URL links
                4. Removes HTML tags
                5. Removes emojis
                
                text - Text piece to be cleaned.
                '''

        data_temp=X.copy()
        data_temp=data_temp.str.replace(r'https?://\S+|www\.\S+',r'')

        # soup = BeautifulSoup(data[col].str., 'lxml') #Removes HTML tags
        # only_text = soup.get_text()
        # data[col] = only_text

        data_temp=data_temp.str.replace("["
                                u"\U0001F600-\U0001F64F"  # emoticons
                                u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                                u"\U0001F680-\U0001F6FF"  # transport &  symbols
                                u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                                u"\U00002702-\U000027B0"
                                u"\U000024C2-\U0001F251"
                                "]+", r'')
        data_temp=data_temp.str.replace(r"[^a-zA-Z\d]", " ")#Remove Extra Spaces
        data_temp=data_temp.str.replace(' +', ' ')#Remove Extra Spaces
        data_temp = data_temp.str.strip()  
        return data_temp

# %%
a=DataCleaner_v0()
print(a.transform(test_clean_df.text))
display(test_clean_df)
# Out:
# 0                                 heyy\n\nkkdsfj
# 1                         hi   how/are/you  ???
# 2                                     hey ?????
# 3                 hey ?????  18.98.333.20 18.98.
# 4               noooo !!!!!!!!!    comeone  !!
# 5    cooooooooool     brooooooooooo  coool brooo
# 6                                   naaaahhhhhhh
# Name: text, dtype: object
#                                           text
# 0                               heyy\n\nkkdsfj
# 1                         hi   how/are/you ???
# 2                                     hey?????
# 3                 hey????? 18.98.333.20 18.98.
# 4                 noooo!!!!!!!!!   comeone !!
# 5  cooooooooool     brooooooooooo  coool brooo
# 6                                 naaaahhhhhhh

# %%
# tfidf_dict=[
#             {"tfidf0":TfidfVectorizer(min_df= 3, max_df=0.5,analyzer = 'char_wb', ngram_range = (3,5))},
#             {"tfidf1":TfidfVectorizer(min_df= 3, max_df=0.5,max_features=2000,analyzer = 'char_wb', ngram_range = (3,5))},
#             {"tfidf2":TfidfVectorizer(min_df= 3, max_df=0.5,analyzer = 'word', ngram_range = (1,2))},
#             {"tfidf3":TfidfVectorizer(min_df= 3, max_df=0.5,analyzer = 'word', ngram_range = (1,5))},
# ]

clean_dict={
            "clean0":DataCleaner_v0(),
            "clean1":DataCleaner_v1(),
}


tfidf_dict={
            "tfidf0":TfidfVectorizer(min_df= 3, max_df=0.5,analyzer = 'char_wb', ngram_range = (3,5)),
            "tfidf1":TfidfVectorizer(min_df= 3, max_df=0.5,max_features=2000,analyzer = 'char_wb', ngram_range = (3,5)),
            "tfidf2":TfidfVectorizer(min_df= 3, max_df=0.5,analyzer = 'word', ngram_range = (1,2)),
            "tfidf3":TfidfVectorizer(min_df= 3, max_df=0.5,analyzer = 'word', ngram_range = (1,5)),
}

model_dict={
            # "lasso":Lasso(),
            "ridge":Ridge(),
            "svm":SVR(kernel="linear"),
            "mlp":MLPRegressor(),            
            "lgb": lgb.LGBMRegressor(objective='regression',
                        num_leaves=31,
                        learning_rate=0.05,
                        n_estimators=20)
}

train_data_dict={'class_train':df_class_train ,
'bias_train':df_bias_train,
'multi_train':df_multi_train,
'ruddit_train':df_ruddit_train}


pipline=Pipeline(
    
    [
        (list(tfidf_dict)[0],list(tfidf_dict.values())[0]),
        (list(model_dict)[1],list(model_dict.values())[1]),
    ]
)




# vectorizer.fit_transform(a.text)
# len(vectorizer.get_feature_names())
# vectorizer.get_feature_names()

# %%
record_path='./record.csv'
                

i=0
for a in range(0,len(list(train_data_dict))):
    for b in range(0,len(list(clean_dict))):
        for c in range(0,len(list(tfidf_dict))):
            for d in range(0,len(list(model_dict))):
                
                print(u'当前进程的内存使用：%.4f GB' % (psutil.Process(os.getpid()).memory_info().rss / 1024 / 1024 / 1024) )               
                record=pd.read_csv(record_path)
                
                if i<record.shape[0]:
                    i+=1
                    continue
                
                print("Version ",i)
                data_name=list(train_data_dict)[a]
                data_model=list(train_data_dict.values())[a]

                clean_name=list(clean_dict)[b]
                clean_model=list(clean_dict.values())[b]

                idf_name=list(tfidf_dict)[c]
                idf_model=list(tfidf_dict.values())[c]

                regression_name=list(model_dict)[d]
                regression_model=list(model_dict.values())[d]


                
                data_size=data_model.shape[0]
          


                size =record.index.size



                pipeline=Pipeline(
                [
                    (clean_name,clean_model),
                    (idf_name,idf_model),
                    (regression_name,regression_model),
                ]
                )
                    

                n_folds=1
                val_preds_arr1_tmp = np.zeros((df_rate_val.shape[0], n_folds))
                val_preds_arr2_tmp = np.zeros((df_rate_val.shape[0], n_folds))
                test_preds_arr_tmp = np.zeros((df_rate_sub.shape[0], n_folds))

                for fld in range(n_folds):

                
                    print(f' ****************************** FOLD: {fld} ******************************')
                    # for test
                    df = data_model.iloc[0:5000,:]

                    #real train
                    # df = data_model
                    # Train the pipeline
                    print('Start Train')
                    start=datetime.now() 
                    pipeline.fit(df['text'], df['y'])
                   
                    print(u'当前进程的内存使用：%.4f GB' % (psutil.Process(os.getpid()).memory_info().rss / 1024 / 1024 / 1024) )    

                    # What are the important features for toxicity
                    feature_number=len(pipeline[idf_name].get_feature_names())
                    print('Total number of features:', feature_number )

                    # feature_wts = sorted(list(zip(pipeline[idf_name].get_feature_names(), 
                    #                                 np.round(pipeline[regression_name].coef_,2) )), 
                    #                         key = lambda x:x[1], 
                    #                         reverse=True)

                    # display(pd.DataFrame(feature_wts[:50], columns = ['feat','val']).T)
                    #.plot('feat','val',kind='barh',figsize = (8,8) )
                    #plt.show()
                    print("predict validation data ")
                    val_preds_arr1_tmp[:,fld] = pipeline.predict(df_rate_val['less_toxic'])
                    val_preds_arr2_tmp[:,fld] = pipeline.predict(df_rate_val['more_toxic'])

                    # print("\npredict test data ")
                    # test_preds_arr_tmp[:,fld] = pipeline.predict(clean_v0(df_rate_sub,'text')['text'])

                    p1 = val_preds_arr1_tmp.mean(axis=1)
                    p2 = val_preds_arr2_tmp.mean(axis=1)
                    

                    val_score=np.round((p1 < p2).mean(),4)
                    print(f'Validation Accuracy is {val_score}')
                    
                    end=datetime.now() 
                    trainning_time=(end-start).seconds
                    
                    model_path='./model/{}.pkl'.format(i)

                    record.loc[size] = [data_name,data_size,clean_name,idf_name,feature_number,regression_name,trainning_time,val_score,model_path]

                    with open('./model/{}.pkl'.format(i),'wb') as fw:
                        pickle.dump(pipeline,fw)

                record.to_csv(record_path,index=False)
                i+=1
    #加载svm.pickle
# with open('new_app_model_v1.pickle','rb') as fr:
#     newpipeline = pickle.load(fr)  
# newpipeline.predict(df_rate_val['more_toxic'])
# Out:
# 当前进程的内存使用：1.0674 GB
# 当前进程的内存使用：1.0675 GB
# 当前进程的内存使用：1.0675 GB
# 当前进程的内存使用：1.0675 GB
# 当前进程的内存使用：1.0675 GB
# 当前进程的内存使用：1.0675 GB
# 当前进程的内存使用：1.0675 GB
# 当前进程的内存使用：1.0675 GB
# 当前进程的内存使用：1.0675 GB
# 当前进程的内存使用：1.0675 GB
# Version  9
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：1.1158 GB
# Total number of features: 21678
# predict validation data
# Validation Accuracy is 0.654
# 当前进程的内存使用：1.1405 GB
# Version  10
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：1.1849 GB
# Total number of features: 21678
# predict validation data
# Validation Accuracy is 0.639
# 当前进程的内存使用：1.1852 GB
# Version  11
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：1.1880 GB
# Total number of features: 21678
# predict validation data
# Validation Accuracy is 0.6168
# 当前进程的内存使用：1.1900 GB
# Version  12
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：1.3020 GB
# Total number of features: 33698
# predict validation data
# Validation Accuracy is 0.6629
# 当前进程的内存使用：1.3044 GB
# Version  13
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：1.3782 GB
# Total number of features: 33698
# predict validation data
# Validation Accuracy is 0.6551
# 当前进程的内存使用：1.3852 GB
# Version  14
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：1.3563 GB
# Total number of features: 33698
# predict validation data
# Validation Accuracy is 0.6489
# 当前进程的内存使用：1.3960 GB
# Version  15
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：1.4121 GB
# Total number of features: 33698
# predict validation data
# Validation Accuracy is 0.6147
# 当前进程的内存使用：1.4146 GB
# Version  16
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：1.4188 GB
# Total number of features: 38170
# predict validation data
# Validation Accuracy is 0.6708
# 当前进程的内存使用：1.4212 GB
# Version  17
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：1.4246 GB
# Total number of features: 38170
# predict validation data
# Validation Accuracy is 0.6568
# 当前进程的内存使用：1.2366 GB
# Version  18
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：1.2352 GB
# Total number of features: 38170
# predict validation data
# Validation Accuracy is 0.6496
# 当前进程的内存使用：1.2520 GB
# Version  19
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：1.2856 GB
# Total number of features: 38170
# predict validation data
# Validation Accuracy is 0.6365
# 当前进程的内存使用：1.2891 GB
# Version  20
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：1.2935 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6542
# 当前进程的内存使用：1.2935 GB
# Version  21
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：1.2919 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6493
# 当前进程的内存使用：0.8824 GB
# Version  22
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8016 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6496
# 当前进程的内存使用：0.8019 GB
# Version  23
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8004 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6215
# 当前进程的内存使用：0.8073 GB
# Version  24
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8025 GB
# Total number of features: 21773
# predict validation data
# Validation Accuracy is 0.6629
# 当前进程的内存使用：0.8046 GB
# Version  25
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8035 GB
# Total number of features: 21773
# predict validation data
# Validation Accuracy is 0.6533
# 当前进程的内存使用：0.8044 GB
# Version  26
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8486 GB
# Total number of features: 21773
# predict validation data
# Validation Accuracy is 0.6424
# 当前进程的内存使用：0.8490 GB
# Version  27
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8501 GB
# Total number of features: 21773
# predict validation data
# Validation Accuracy is 0.6157
# 当前进程的内存使用：0.8528 GB
# Version  28
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8614 GB
# Total number of features: 33764
# predict validation data
# Validation Accuracy is 0.6637
# 当前进程的内存使用：0.8624 GB
# Version  29
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8624 GB
# Total number of features: 33764
# predict validation data
# Validation Accuracy is 0.6553
# 当前进程的内存使用：0.8635 GB
# Version  30
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8875 GB
# Total number of features: 33764
# predict validation data
# Validation Accuracy is 0.6408
# 当前进程的内存使用：0.8878 GB
# Version  31
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8901 GB
# Total number of features: 33764
# predict validation data
# Validation Accuracy is 0.6144
# 当前进程的内存使用：0.8913 GB
# Version  32
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9058 GB
# Total number of features: 47194
# predict validation data
# Validation Accuracy is 0.6382
# 当前进程的内存使用：0.9072 GB
# Version  33
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9107 GB
# Total number of features: 47194
# predict validation data
# Validation Accuracy is 0.6325
# 当前进程的内存使用：0.9493 GB
# Version  34
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9027 GB
# Total number of features: 47194
# predict validation data
# Validation Accuracy is 0.6246
# 当前进程的内存使用：0.9272 GB
# Version  35
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9481 GB
# Total number of features: 47194
# predict validation data
# Validation Accuracy is 0.5498
# 当前进程的内存使用：0.9569 GB
# Version  36
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9589 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.5968
# 当前进程的内存使用：0.9619 GB
# Version  37
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9592 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.5858
# 当前进程的内存使用：0.9627 GB
# Version  38
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8600 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.582
# 当前进程的内存使用：0.8486 GB
# Version  39
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8458 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.5512
# 当前进程的内存使用：0.8462 GB
# Version  40
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8457 GB
# Total number of features: 19154
# predict validation data
# Validation Accuracy is 0.5735
# 当前进程的内存使用：0.8463 GB
# Version  41
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8453 GB
# Total number of features: 19154
# predict validation data
# Validation Accuracy is 0.5581
# 当前进程的内存使用：0.8455 GB
# Version  42
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8839 GB
# Total number of features: 19154
# predict validation data
# Validation Accuracy is 0.5703
# 当前进程的内存使用：0.8839 GB
# Version  43
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8909 GB
# Total number of features: 19154
# predict validation data
# Validation Accuracy is 0.4866
# 当前进程的内存使用：0.8930 GB
# Version  44
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8980 GB
# Total number of features: 23333
# predict validation data
# Validation Accuracy is 0.5743
# 当前进程的内存使用：0.8982 GB
# Version  45
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8965 GB
# Total number of features: 23333
# predict validation data
# Validation Accuracy is 0.5584
# 当前进程的内存使用：0.8965 GB
# Version  46
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9058 GB
# Total number of features: 23333
# predict validation data
# Validation Accuracy is 0.5376
# 当前进程的内存使用：0.9058 GB
# Version  47
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9087 GB
# Total number of features: 23333
# predict validation data
# Validation Accuracy is 0.5002
# 当前进程的内存使用：0.8712 GB
# Version  48
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8686 GB
# Total number of features: 36406
# predict validation data
# Validation Accuracy is 0.6403
# 当前进程的内存使用：0.8699 GB
# Version  49
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8719 GB
# Total number of features: 36406
# predict validation data
# Validation Accuracy is 0.6343
# 当前进程的内存使用：0.8754 GB
# Version  50
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9046 GB
# Total number of features: 36406
# predict validation data
# Validation Accuracy is 0.6231
# 当前进程的内存使用：0.9046 GB
# Version  51
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9068 GB
# Total number of features: 36406
# predict validation data
# Validation Accuracy is 0.5363
# 当前进程的内存使用：0.8899 GB
# Version  52
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8855 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.5969
# 当前进程的内存使用：0.8857 GB
# Version  53
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8841 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.5863
# 当前进程的内存使用：0.8841 GB
# Version  54
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8072 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.5806
# 当前进程的内存使用：0.8072 GB
# Version  55
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8051 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.5439
# 当前进程的内存使用：0.8055 GB
# Version  56
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8055 GB
# Total number of features: 19049
# predict validation data
# Validation Accuracy is 0.5731
# 当前进程的内存使用：0.8060 GB
# Version  57
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8060 GB
# Total number of features: 19049
# predict validation data
# Validation Accuracy is 0.5587
# 当前进程的内存使用：0.8069 GB
# Version  58
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8451 GB
# Total number of features: 19049
# predict validation data
# Validation Accuracy is 0.5786
# 当前进程的内存使用：0.8451 GB
# Version  59
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8443 GB
# Total number of features: 19049
# predict validation data
# Validation Accuracy is 0.5014
# 当前进程的内存使用：0.8485 GB
# Version  60
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8468 GB
# Total number of features: 23198
# predict validation data
# Validation Accuracy is 0.5734
# 当前进程的内存使用：0.8465 GB
# Version  61
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8468 GB
# Total number of features: 23198
# predict validation data
# Validation Accuracy is 0.5573
# 当前进程的内存使用：0.8437 GB
# Version  62
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8532 GB
# Total number of features: 23198
# predict validation data
# Validation Accuracy is 0.5586
# 当前进程的内存使用：0.8532 GB
# Version  63
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8525 GB
# Total number of features: 23198
# predict validation data
# Validation Accuracy is 0.4698
# 当前进程的内存使用：0.8525 GB
# Version  64
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8603 GB
# Total number of features: 51474
# predict validation data
# Validation Accuracy is 0.6717
# 当前进程的内存使用：0.8604 GB
# Version  65
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8637 GB
# Total number of features: 51474
# predict validation data
# Validation Accuracy is 0.6607
# 当前进程的内存使用：0.8706 GB
# Version  66
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9225 GB
# Total number of features: 51474
# predict validation data
# Validation Accuracy is 0.6537
# 当前进程的内存使用：0.9227 GB
# Version  67
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9206 GB
# Total number of features: 51474
# predict validation data
# Validation Accuracy is 0.644
# 当前进程的内存使用：0.9210 GB
# Version  68
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9294 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.652
# 当前进程的内存使用：0.9294 GB
# Version  69
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9274 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6453
# 当前进程的内存使用：0.9143 GB
# Version  70
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8037 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6416
# 当前进程的内存使用：0.8038 GB
# Version  71
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8033 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6228
# 当前进程的内存使用：0.8034 GB
# Version  72
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8122 GB
# Total number of features: 21678
# predict validation data
# Validation Accuracy is 0.6631
# 当前进程的内存使用：0.8122 GB
# Version  73
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8109 GB
# Total number of features: 21678
# predict validation data
# Validation Accuracy is 0.654
# 当前进程的内存使用：0.8109 GB
# Version  74
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8549 GB
# Total number of features: 21678
# predict validation data
# Validation Accuracy is 0.6484
# 当前进程的内存使用：0.8549 GB
# Version  75
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8554 GB
# Total number of features: 21678
# predict validation data
# Validation Accuracy is 0.6168
# 当前进程的内存使用：0.8633 GB
# Version  76
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8665 GB
# Total number of features: 33698
# predict validation data
# Validation Accuracy is 0.6629
# 当前进程的内存使用：0.8666 GB
# Version  77
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8797 GB
# Total number of features: 33698
# predict validation data
# Validation Accuracy is 0.6551
# 当前进程的内存使用：0.8643 GB
# Version  78
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8907 GB
# Total number of features: 33698
# predict validation data
# Validation Accuracy is 0.6477
# 当前进程的内存使用：0.8910 GB
# Version  79
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8932 GB
# Total number of features: 33698
# predict validation data
# Validation Accuracy is 0.6147
# 当前进程的内存使用：0.8936 GB
# Version  80
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8917 GB
# Total number of features: 38170
# predict validation data
# Validation Accuracy is 0.6708
# 当前进程的内存使用：0.8920 GB
# Version  81
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8953 GB
# Total number of features: 38170
# predict validation data
# Validation Accuracy is 0.6568
# 当前进程的内存使用：0.8952 GB
# Version  82
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9042 GB
# Total number of features: 38170
# predict validation data
# Validation Accuracy is 0.655
# 当前进程的内存使用：0.9042 GB
# Version  83
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9053 GB
# Total number of features: 38170
# predict validation data
# Validation Accuracy is 0.6365
# 当前进程的内存使用：0.9116 GB
# Version  84
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9081 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6542
# 当前进程的内存使用：0.9115 GB
# Version  85
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.9098 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6493
# 当前进程的内存使用：0.9101 GB
# Version  86
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8284 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6445
# 当前进程的内存使用：0.8288 GB
# Version  87
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8256 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6215
# 当前进程的内存使用：0.8258 GB
# Version  88
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8219 GB
# Total number of features: 21773
# predict validation data
# Validation Accuracy is 0.6629
# 当前进程的内存使用：0.8219 GB
# Version  89
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8206 GB
# Total number of features: 21773
# predict validation data
# Validation Accuracy is 0.6533
# 当前进程的内存使用：0.8208 GB
# Version  90
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8650 GB
# Total number of features: 21773
# predict validation data
# Validation Accuracy is 0.6459
# 当前进程的内存使用：0.8650 GB
# Version  91
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8650 GB
# Total number of features: 21773
# predict validation data
# Validation Accuracy is 0.6157
# 当前进程的内存使用：0.8651 GB
# Version  92
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8649 GB
# Total number of features: 33764
# predict validation data
# Validation Accuracy is 0.6637
# 当前进程的内存使用：0.8647 GB
# Version  93
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8652 GB
# Total number of features: 33764
# predict validation data
# Validation Accuracy is 0.6553
# 当前进程的内存使用：0.8652 GB
# Version  94
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8925 GB
# Total number of features: 33764
# predict validation data
# Validation Accuracy is 0.6424
# 当前进程的内存使用：0.8727 GB
# Version  95
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8753 GB
# Total number of features: 33764
# predict validation data
# Validation Accuracy is 0.6144
# 当前进程的内存使用：0.8750 GB
# Version  96
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8749 GB
# Total number of features: 34194
# predict validation data
# Validation Accuracy is 0.6324
# 当前进程的内存使用：0.8751 GB
# Version  97
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8806 GB
# Total number of features: 34194
# predict validation data
# Validation Accuracy is 0.6292
# 当前进程的内存使用：0.8754 GB
# Version  98
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8737 GB
# Total number of features: 34194
# predict validation data
# Validation Accuracy is 0.628
# 当前进程的内存使用：0.8759 GB
# Version  99
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8801 GB
# Total number of features: 34194
# predict validation data
# Validation Accuracy is 0.5868
# 当前进程的内存使用：0.8801 GB
# Version  100
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8758 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6107
# 当前进程的内存使用：0.8853 GB
# Version  101
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8832 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6128
# 当前进程的内存使用：0.8842 GB
# Version  102
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8122 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6134
# 当前进程的内存使用：0.8124 GB
# Version  103
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8106 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.5808
# 当前进程的内存使用：0.8183 GB
# Version  104
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8132 GB
# Total number of features: 13492
# predict validation data
# Validation Accuracy is 0.6189
# 当前进程的内存使用：0.8141 GB
# Version  105
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8108 GB
# Total number of features: 13492
# predict validation data
# Validation Accuracy is 0.6156
# 当前进程的内存使用：0.8112 GB
# Version  106
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8149 GB
# Total number of features: 13492
# predict validation data
# Validation Accuracy is 0.6102
# 当前进程的内存使用：0.8152 GB
# Version  107
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8152 GB
# Total number of features: 13492
# predict validation data
# Validation Accuracy is 0.5828
# 当前进程的内存使用：0.8167 GB
# Version  108
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7725 GB
# Total number of features: 16938
# predict validation data
# Validation Accuracy is 0.6183
# 当前进程的内存使用：0.7784 GB
# Version  109
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7752 GB
# Total number of features: 16938
# predict validation data
# Validation Accuracy is 0.6153
# 当前进程的内存使用：0.7754 GB
# Version  110
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7827 GB
# Total number of features: 16938
# predict validation data
# Validation Accuracy is 0.6006
# 当前进程的内存使用：0.7828 GB
# Version  111
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7828 GB
# Total number of features: 16938
# predict validation data
# Validation Accuracy is 0.5816
# 当前进程的内存使用：0.7830 GB
# Version  112
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7821 GB
# Total number of features: 28008
# predict validation data
# Validation Accuracy is 0.6303
# 当前进程的内存使用：0.7821 GB
# Version  113
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7873 GB
# Total number of features: 28008
# predict validation data
# Validation Accuracy is 0.6299
# 当前进程的内存使用：0.7767 GB
# Version  114
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8014 GB
# Total number of features: 28008
# predict validation data
# Validation Accuracy is 0.617
# 当前进程的内存使用：0.7951 GB
# Version  115
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8040 GB
# Total number of features: 28008
# predict validation data
# Validation Accuracy is 0.5872
# 当前进程的内存使用：0.8026 GB
# Version  116
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8029 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6109
# 当前进程的内存使用：0.8036 GB
# Version  117
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.8017 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.617
# 当前进程的内存使用：0.8024 GB
# Version  118
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7443 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.6124
# 当前进程的内存使用：0.7443 GB
# Version  119
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7427 GB
# Total number of features: 2000
# predict validation data
# Validation Accuracy is 0.5809
# 当前进程的内存使用：0.7440 GB
# Version  120
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7462 GB
# Total number of features: 13490
# predict validation data
# Validation Accuracy is 0.6194
# 当前进程的内存使用：0.7526 GB
# Version  121
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7493 GB
# Total number of features: 13490
# predict validation data
# Validation Accuracy is 0.6158
# 当前进程的内存使用：0.7307 GB
# Version  122
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7564 GB
# Total number of features: 13490
# predict validation data
# Validation Accuracy is 0.608
# 当前进程的内存使用：0.7567 GB
# Version  123
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7567 GB
# Total number of features: 13490
# predict validation data
# Validation Accuracy is 0.5829
# 当前进程的内存使用：0.7567 GB
# Version  124
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7603 GB
# Total number of features: 16937
# predict validation data
# Validation Accuracy is 0.6185
# 当前进程的内存使用：0.7618 GB
# Version  125
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7613 GB
# Total number of features: 16937
# predict validation data
# Validation Accuracy is 0.6148
# 当前进程的内存使用：0.7618 GB
# Version  126
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7695 GB
# Total number of features: 16937
# predict validation data
# Validation Accuracy is 0.597
# 当前进程的内存使用：0.7700 GB
# Version  127
#  ****************************** FOLD: 0 ******************************
# Start Train
# 当前进程的内存使用：0.7697 GB
# Total number of features: 16937
# predict validation data
# Validation Accuracy is 0.5825
